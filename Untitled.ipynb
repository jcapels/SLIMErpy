# %%
import cobra

# %%
model = cobra.io.load_matlab_model("yeast780.mat")

# %%
cobra.io.write_sbml_model(model,"yeast.xml")

# %%
model = cobra.io.read_sbml_model("yeast.xml")

# %%
model.metabolites
# Out:
# [<Metabolite s_0001[ce] at 0x7f9335812d90>,
#  <Metabolite s_0002[c] at 0x7f9335812e50>,
#  <Metabolite s_0003[e] at 0x7f9335812f10>,
#  <Metabolite s_0004[ce] at 0x7f9335812fd0>,
#  <Metabolite s_0006[m] at 0x7f93357f0050>,
#  <Metabolite s_0007[c] at 0x7f93357f01d0>,
#  <Metabolite s_0008[m] at 0x7f93357f0290>,
#  <Metabolite s_0009[c] at 0x7f93357f0350>,
#  <Metabolite s_0010[c] at 0x7f93357f0410>,
#  <Metabolite s_0011[m] at 0x7f93357f0190>,
#  <Metabolite s_0012[m] at 0x7f93357f0550>,
#  <Metabolite s_0013[c] at 0x7f93357f0610>,
#  <Metabolite s_0014[n] at 0x7f93357f06d0>,
#  <Metabolite s_0015[c] at 0x7f93357f0790>,
#  <Metabolite s_0016[m] at 0x7f93357f0850>,
#  <Metabolite s_0017[c] at 0x7f93357f0910>,
#  <Metabolite s_0018[c] at 0x7f93357f09d0>,
#  <Metabolite s_0019[c] at 0x7f93357f0a90>,
#  <Metabolite s_0020[c] at 0x7f93357f0b50>,
#  <Metabolite s_0021[c] at 0x7f93357f0c10>,
#  <Metabolite s_0022[e] at 0x7f93357f0cd0>,
#  <Metabolite s_0023[m] at 0x7f93357f0d90>,
# ...

# %%
model.reactions
# Out:
# [<Reaction r_0001 at 0x7f93357d5f50>,
#  <Reaction r_0002 at 0x7f93356d60d0>,
#  <Reaction r_0003 at 0x7f93356d6710>,
#  <Reaction r_0004 at 0x7f93356d6850>,
#  <Reaction r_0005 at 0x7f93356d6c50>,
#  <Reaction r_0006 at 0x7f93356d6fd0>,
#  <Reaction r_0007 at 0x7f93356dc4d0>,
#  <Reaction r_0012 at 0x7f93356dc490>,
#  <Reaction r_0013 at 0x7f93356dc910>,
#  <Reaction r_0014 at 0x7f93356dc890>,
#  <Reaction r_0015 at 0x7f93356e2310>,
#  <Reaction r_0016 at 0x7f93356e2850>,
#  <Reaction r_0017 at 0x7f93356e28d0>,
#  <Reaction r_0018 at 0x7f93356eb290>,
#  <Reaction r_0019 at 0x7f93356eb690>,
#  <Reaction r_0020 at 0x7f93356ebb10>,
#  <Reaction r_0021 at 0x7f93356eb210>,
#  <Reaction r_0022 at 0x7f93356f2390>,
#  <Reaction r_0023 at 0x7f93356f2810>,
#  <Reaction r_0024 at 0x7f93356f2c90>,
#  <Reaction r_0025 at 0x7f93356f27d0>,
#  <Reaction r_0026 at 0x7f93356f84d0>,
#  <Reaction r_0027 at 0x7f93356f8850>,
#  <Reaction r_0028 at 0x7f93356f8d90>,
#  <Reaction r_0029 at 0x7f93356f8890>,
# ...
